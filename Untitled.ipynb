# %%
import pandas as pd

from matplotlib import pyplot as plt

# %%
data = pd.read_csv('piechart.csv')
data
# Out:
#    Time   Human Resources   Variation in Student Background  \
# 0     4                 4                                 4
#
#     Diffusion of Resources
# 0                         4

# %%
Obstacles = ['Time', 'Human Resources', 'Variation in Student Background', 'Diffusion of Resources']
Responses = [4, 4, 4, 4]

actualFigure = plt.figure(figsize = (8,8))
actualFigure.suptitle("Obstacles to ILI", fontsize=22)

pie = plt.pie(Responses, labels=Obstacles, autopct='%1.0f%%')
